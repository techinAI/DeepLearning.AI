# %% [markdown]
# # Keras tutorial - the Happy House
#
# Welcome to the first assignment of week 2. In this assignment, you will:
# 1. Learn to use Keras, a high-level neural networks API (programming framework), written in Python and capable of running on top of several lower-level frameworks including TensorFlow and CNTK.
# 2. See how you can in a couple of hours build a deep learning algorithm.
#
# Why are we using Keras? Keras was developed to enable deep learning engineers to build and experiment with different models very quickly. Just as TensorFlow is a higher-level framework than Python, Keras is an even higher-level framework and provides additional abstractions. Being able to go from idea to result with the least possible delay is key to finding good models. However, Keras is more restrictive than the lower-level frameworks, so there are some very complex models that you can implement in TensorFlow but not (without more difficulty) in Keras. That being said, Keras will work fine for many common models.
#
# In this exercise, you'll work on the "Happy House" problem, which we'll explain below. Let's load the required packages and solve the problem of the Happy House!

# %%
import numpy as np
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from kt_utils import *

import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# !tar cvfz notebook.tar.gz *
# Out:
# __pycache__/
# dummy/
# dummy/__pycache__/
# readonly/
# readonly/readonly/
# week1/
# week1/.ipynb_checkpoints/
# week1/.ipynb_checkpoints/Convolution model - Application - v1-checkpoint.ipynb
# week1/.ipynb_checkpoints/Convolution model - Step by Step - v2-checkpoint.ipynb
# week1/Convolution model - Step by Step - v2.ipynb
# week1/Convolution model - Application - v1.ipynb
# week1/cnn_utils.py
# week1/images/
# week1/images/PAD.png
# week1/images/model.png
# week1/images/conv_nn.png
# week1/images/Convolution_schematic.gif
# week1/images/vert_horiz_kiank.png
# week1/images/conv_kiank.mp4
# week1/images/max_pool.png
# week1/images/conv1.png
# week1/images/ave-pool.png
# week1/images/thumbs_up.jpg
# week1/images/ave_pool1.png
# week1/images/conv.png
# week1/images/a_pool.png
# week1/images/max_pool1.png
# week1/images/SIGNS.png
# week1/images/average_pool.png
# week1/datasets/
# week1/datasets/train_signs.h5
# week1/datasets/test_signs.h5
# week1/__pycache__/
# week1/__pycache__/cnn_utils.cpython-36.pyc
# week1/Convolution model - Step by Step - v1.ipynb
# week2/
# week2/ResNets/
# week2/ResNets/model.png
# week2/ResNets/Residual Networks - v1.ipynb
# week2/ResNets/.ipynb_checkpoints/
# week2/ResNets/.ipynb_checkpoints/Residual Networks - v2-checkpoint.ipynb
# week2/ResNets/images/
# week2/ResNets/images/vanishing_grad_kiank.png
# week2/ResNets/images/idblock2_kiank.png
# week2/ResNets/images/skip_connection_kiank.png
# week2/ResNets/images/convblock_kiank.png
# week2/ResNets/images/resnet_kiank.png
# week2/ResNets/images/signs_data_kiank.png
# week2/ResNets/images/idblock3_kiank.png
# week2/ResNets/images/my_image.jpg
# week2/ResNets/ResNet50.h5
# week2/ResNets/datasets/
# week2/ResNets/datasets/train_signs.h5
# week2/ResNets/datasets/test_signs.h5
# week2/ResNets/__pycache__/
# week2/ResNets/__pycache__/resnets_utils.cpython-36.pyc
# week2/ResNets/resnets_utils.py
# week2/ResNets/Residual Networks - v2.ipynb
# week2/KerasTutorial/
# week2/KerasTutorial/Keras - Tutorial - Happy House v2.ipynb
# week2/KerasTutorial/.ipynb_checkpoints/
# week2/KerasTutorial/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# week2/KerasTutorial/.ipynb_checkpoints/Keras - Tutorial - Happy House v2-checkpoint.ipynb
# week2/KerasTutorial/images/
# week2/KerasTutorial/images/happy-house.jpg
# week2/KerasTutorial/images/my_image.jpg
# week2/KerasTutorial/images/house-members.png
# week2/KerasTutorial/kt_utils.py
# week2/KerasTutorial/Keras - Tutorial - Happy House v1.ipynb
# week2/KerasTutorial/datasets/
# week2/KerasTutorial/datasets/test_happy.h5
# week2/KerasTutorial/datasets/train_happy.h5
# week2/KerasTutorial/Untitled.ipynb
# week2/KerasTutorial/__pycache__/
# week2/KerasTutorial/__pycache__/kt_utils.cpython-36.pyc
# week2/KerasTutorial/notebook.tar.gz
# week2/__pycache__/
# week3/
# week3/Car detection for Autonomous Driving/
# week3/Car detection for Autonomous Driving/out/
# week3/Car detection for Autonomous Driving/out/test.jpg
# week3/Car detection for Autonomous Driving/model_data/
# week3/Car detection for Autonomous Driving/model_data/object_classes.txt
# week3/Car detection for Autonomous Driving/model_data/yolo.h5
# week3/Car detection for Autonomous Driving/model_data/yolo_anchors.txt
# week3/Car detection for Autonomous Driving/model_data/coco_classes.txt
# week3/Car detection for Autonomous Driving/yolo_utils.py
# week3/Car detection for Autonomous Driving/.ipynb_checkpoints/
# week3/Car detection for Autonomous Driving/.ipynb_checkpoints/Autonomous driving application - Car detection - v1-checkpoint.ipynb
# week3/Car detection for Autonomous Driving/images/
# week3/Car detection for Autonomous Driving/images/0010.jpg
# week3/Car detection for Autonomous Driving/images/0089.jpg
# week3/Car detection for Autonomous Driving/images/0001.jpg
# week3/Car detection for Autonomous Driving/images/0100.jpg
# week3/Car detection for Autonomous Driving/images/0098.jpg
# week3/Car detection for Autonomous Driving/images/0117.jpg
# week3/Car detection for Autonomous Driving/images/0036.jpg
# week3/Car detection for Autonomous Driving/images/0072.jpg
# week3/Car detection for Autonomous Driving/images/0054.jpg
# week3/Car detection for Autonomous Driving/images/0018.jpg
# week3/Car detection for Autonomous Driving/images/0090.jpg
# week3/Car detection for Autonomous Driving/images/0045.jpg
# week3/Car detection for Autonomous Driving/images/0009.jpg
# week3/Car detection for Autonomous Driving/images/0081.jpg
# week3/Car detection for Autonomous Driving/images/0063.jpg
# week3/Car detection for Autonomous Driving/images/0108.jpg
# week3/Car detection for Autonomous Driving/images/0027.jpg
# week3/Car detection for Autonomous Driving/images/0032.jpg
# week3/Car detection for Autonomous Driving/images/0113.jpg
# week3/Car detection for Autonomous Driving/images/0050.jpg
# week3/Car detection for Autonomous Driving/images/0014.jpg
# week3/Car detection for Autonomous Driving/images/0041.jpg
# week3/Car detection for Autonomous Driving/images/0005.jpg
# week3/Car detection for Autonomous Driving/images/0023.jpg
# week3/Car detection for Autonomous Driving/images/0104.jpg
# week3/Car detection for Autonomous Driving/images/0076.jpg
# week3/Car detection for Autonomous Driving/images/0058.jpg
# week3/Car detection for Autonomous Driving/images/0094.jpg
# week3/Car detection for Autonomous Driving/images/0049.jpg
# week3/Car detection for Autonomous Driving/images/0085.jpg
# week3/Car detection for Autonomous Driving/images/0067.jpg
# week3/Car detection for Autonomous Driving/images/0030.jpg
# week3/Car detection for Autonomous Driving/images/0111.jpg
# week3/Car detection for Autonomous Driving/images/0012.jpg
# week3/Car detection for Autonomous Driving/images/0120.jpg
# week3/Car detection for Autonomous Driving/images/0003.jpg
# week3/Car detection for Autonomous Driving/images/0102.jpg
# week3/Car detection for Autonomous Driving/images/0021.jpg
# week3/Car detection for Autonomous Driving/images/0038.jpg
# week3/Car detection for Autonomous Driving/images/0119.jpg
# week3/Car detection for Autonomous Driving/images/0074.jpg
# week3/Car detection for Autonomous Driving/images/0056.jpg
# week3/Car detection for Autonomous Driving/images/0092.jpg
# week3/Car detection for Autonomous Driving/images/0047.jpg
# week3/Car detection for Autonomous Driving/images/0083.jpg
# week3/Car detection for Autonomous Driving/images/0065.jpg
# week3/Car detection for Autonomous Driving/images/0029.jpg
# week3/Car detection for Autonomous Driving/images/0115.jpg
# week3/Car detection for Autonomous Driving/images/0034.jpg
# week3/Car detection for Autonomous Driving/images/0070.jpg
# week3/Car detection for Autonomous Driving/images/0052.jpg
# week3/Car detection for Autonomous Driving/images/0016.jpg
# week3/Car detection for Autonomous Driving/images/0043.jpg
# week3/Car detection for Autonomous Driving/images/0007.jpg
# week3/Car detection for Autonomous Driving/images/0061.jpg
# week3/Car detection for Autonomous Driving/images/0025.jpg
# week3/Car detection for Autonomous Driving/images/0106.jpg
# week3/Car detection for Autonomous Driving/images/0078.jpg
# week3/Car detection for Autonomous Driving/images/0096.jpg
# week3/Car detection for Autonomous Driving/images/0087.jpg
# week3/Car detection for Autonomous Driving/images/0069.jpg
# week3/Car detection for Autonomous Driving/images/0110.jpg
# week3/Car detection for Autonomous Driving/images/0011.jpg
# week3/Car detection for Autonomous Driving/images/0002.jpg
# week3/Car detection for Autonomous Driving/images/0099.jpg
# week3/Car detection for Autonomous Driving/images/0101.jpg
# week3/Car detection for Autonomous Driving/images/0020.jpg
# week3/Car detection for Autonomous Driving/images/0073.jpg
# week3/Car detection for Autonomous Driving/images/0118.jpg
# week3/Car detection for Autonomous Driving/images/0037.jpg
# week3/Car detection for Autonomous Driving/images/0091.jpg
# week3/Car detection for Autonomous Driving/images/0019.jpg
# week3/Car detection for Autonomous Driving/images/0055.jpg
# week3/Car detection for Autonomous Driving/images/0082.jpg
# week3/Car detection for Autonomous Driving/images/0046.jpg
# week3/Car detection for Autonomous Driving/images/0109.jpg
# week3/Car detection for Autonomous Driving/images/0028.jpg
# week3/Car detection for Autonomous Driving/images/0064.jpg
# week3/Car detection for Autonomous Driving/images/0033.jpg
# week3/Car detection for Autonomous Driving/images/0114.jpg
# week3/Car detection for Autonomous Driving/images/0015.jpg
# week3/Car detection for Autonomous Driving/images/0051.jpg
# week3/Car detection for Autonomous Driving/images/0006.jpg
# week3/Car detection for Autonomous Driving/images/0042.jpg
# week3/Car detection for Autonomous Driving/images/0024.jpg
# week3/Car detection for Autonomous Driving/images/0105.jpg
# week3/Car detection for Autonomous Driving/images/0060.jpg
# week3/Car detection for Autonomous Driving/images/0077.jpg
# week3/Car detection for Autonomous Driving/images/0095.jpg
# week3/Car detection for Autonomous Driving/images/0059.jpg
# week3/Car detection for Autonomous Driving/images/0086.jpg
# week3/Car detection for Autonomous Driving/images/0068.jpg
# week3/Car detection for Autonomous Driving/images/0031.jpg
# week3/Car detection for Autonomous Driving/images/0112.jpg
# week3/Car detection for Autonomous Driving/images/0013.jpg
# week3/Car detection for Autonomous Driving/images/giraffe.jpg
# week3/Car detection for Autonomous Driving/images/0004.jpg
# week3/Car detection for Autonomous Driving/images/0040.jpg
# week3/Car detection for Autonomous Driving/images/0022.jpg
# week3/Car detection for Autonomous Driving/images/0103.jpg
# week3/Car detection for Autonomous Driving/images/0075.jpg
# week3/Car detection for Autonomous Driving/images/0039.jpg
# week3/Car detection for Autonomous Driving/images/0093.jpg
# week3/Car detection for Autonomous Driving/images/0057.jpg
# week3/Car detection for Autonomous Driving/images/0084.jpg
# week3/Car detection for Autonomous Driving/images/0048.jpg
# week3/Car detection for Autonomous Driving/images/0066.jpg
# week3/Car detection for Autonomous Driving/images/0071.jpg
# week3/Car detection for Autonomous Driving/images/0116.jpg
# week3/Car detection for Autonomous Driving/images/0035.jpg
# week3/Car detection for Autonomous Driving/images/0017.jpg
# week3/Car detection for Autonomous Driving/images/0053.jpg
# week3/Car detection for Autonomous Driving/images/0008.jpg
# week3/Car detection for Autonomous Driving/images/0080.jpg
# week3/Car detection for Autonomous Driving/images/0044.jpg
# week3/Car detection for Autonomous Driving/images/0107.jpg
# week3/Car detection for Autonomous Driving/images/0026.jpg
# week3/Car detection for Autonomous Driving/images/0062.jpg
# week3/Car detection for Autonomous Driving/images/0079.jpg
# week3/Car detection for Autonomous Driving/images/0097.jpg
# week3/Car detection for Autonomous Driving/images/test.jpg
# week3/Car detection for Autonomous Driving/images/0088.jpg
# week3/Car detection for Autonomous Driving/__pycache__/
# week3/Car detection for Autonomous Driving/__pycache__/yolo_utils.cpython-36.pyc
# week3/Car detection for Autonomous Driving/nb_images/
# week3/Car detection for Autonomous Driving/nb_images/pred_video.mp4
# week3/Car detection for Autonomous Driving/nb_images/iou.png
# week3/Car detection for Autonomous Driving/nb_images/proba_map.png
# week3/Car detection for Autonomous Driving/nb_images/probability_extraction.png
# week3/Car detection for Autonomous Driving/nb_images/prediction_video_compressed.mp4
# week3/Car detection for Autonomous Driving/nb_images/pred_video_compressed2.mp4
# week3/Car detection for Autonomous Driving/nb_images/architecture.png
# week3/Car detection for Autonomous Driving/nb_images/road_video_compressed2.mp4
# week3/Car detection for Autonomous Driving/nb_images/flatten.png
# week3/Car detection for Autonomous Driving/nb_images/non-max-suppression.png
# week3/Car detection for Autonomous Driving/nb_images/box_label.png
# week3/Car detection for Autonomous Driving/nb_images/anchor_map.png
# week3/Car detection for Autonomous Driving/nb_images/road_video.mp4
# week3/Car detection for Autonomous Driving/nb_images/driveai.png
# week3/Car detection for Autonomous Driving/nb_images/road_video_compressed.mp4
# week3/Car detection for Autonomous Driving/Drive.ai Dataset Sample LICENSE
# week3/Car detection for Autonomous Driving/LICENSE
# week3/Car detection for Autonomous Driving/yad2k/
# week3/Car detection for Autonomous Driving/yad2k/models/
# week3/Car detection for Autonomous Driving/yad2k/models/__pycache__/
# week3/Car detection for Autonomous Driving/yad2k/models/__pycache__/keras_yolo.cpython-36.pyc
# week3/Car detection for Autonomous Driving/yad2k/models/__pycache__/keras_darknet19.cpython-36.pyc
# week3/Car detection for Autonomous Driving/yad2k/models/keras_darknet19.py
# week3/Car detection for Autonomous Driving/yad2k/models/keras_yolo.py
# week3/Car detection for Autonomous Driving/yad2k/utils/
# week3/Car detection for Autonomous Driving/yad2k/utils/utils.py
# week3/Car detection for Autonomous Driving/yad2k/utils/__pycache__/
# week3/Car detection for Autonomous Driving/yad2k/utils/__pycache__/utils.cpython-36.pyc
# week3/Car detection for Autonomous Driving/yad2k/utils/__pycache__/__init__.cpython-36.pyc
# week3/Car detection for Autonomous Driving/yad2k/utils/__init__.py
# week3/Car detection for Autonomous Driving/font/
# week3/Car detection for Autonomous Driving/font/FiraMono-Medium.otf
# week3/Car detection for Autonomous Driving/font/SIL Open Font License.txt
# week3/Car detection for Autonomous Driving/Autonomous driving application - Car detection - v1.ipynb
# week4/
# week4/Face Recognition/
# week4/Face Recognition/inception_blocks_v2.py
# week4/Face Recognition/Face Recognition for the Happy House - v3.ipynb
# week4/Face Recognition/Face Recognition for the Happy House - v1.ipynb
# week4/Face Recognition/.ipynb_checkpoints/
# week4/Face Recognition/.ipynb_checkpoints/Face Recognition for the Happy House - v3-checkpoint.ipynb
# week4/Face Recognition/images/
# week4/Face Recognition/images/benoit.jpg
# week4/Face Recognition/images/f_x.png
# week4/Face Recognition/images/andrew.jpg
# week4/Face Recognition/images/sebastiano.jpg
# week4/Face Recognition/images/inception_block1a.png
# week4/Face Recognition/images/camera_1.jpg
# week4/Face Recognition/images/kevin.jpg
# week4/Face Recognition/images/camera_5.jpg
# week4/Face Recognition/images/younes.jpg
# week4/Face Recognition/images/dan.jpg
# week4/Face Recognition/images/distance_matrix.png
# week4/Face Recognition/images/kian.jpg
# week4/Face Recognition/images/arnaud.jpg
# week4/Face Recognition/images/camera_3.jpg
# week4/Face Recognition/images/danielle.png
# week4/Face Recognition/images/bertrand.jpg
# week4/Face Recognition/images/triplet_comparison.png
# week4/Face Recognition/images/camera_2.jpg
# week4/Face Recognition/images/tian.jpg
# week4/Face Recognition/images/distance_kiank.png
# week4/Face Recognition/images/camera_4.jpg
# week4/Face Recognition/images/felix.jpg
# week4/Face Recognition/images/camera_0.jpg
# week4/Face Recognition/images/pixel_comparison.png
# week4/Face Recognition/datasets/
# week4/Face Recognition/datasets/test_happy.h5
# week4/Face Recognition/datasets/train_happy.h5
# week4/Face Recognition/datasets/train_face.h5
# week4/Face Recognition/__pycache__/
# week4/Face Recognition/__pycache__/inception_blocks_v2.cpython-36.pyc
# week4/Face Recognition/__pycache__/fr_utils.cpython-36.pyc
# week4/Face Recognition/Face Recognition for the Happy House - v2.ipynb
# week4/Face Recognition/weights/
# week4/Face Recognition/weights/inception_4a_5x5_conv2_b.csv
# week4/Face Recognition/weights/inception_3a_3x3_conv2_w.csv
# week4/Face Recognition/weights/inception_3a_3x3_bn2_m.csv
# week4/Face Recognition/weights/inception_4e_3x3_conv2_b.csv
# week4/Face Recognition/weights/inception_3b_3x3_bn1_m.csv
# week4/Face Recognition/weights/inception_3b_3x3_conv1_w.csv
# week4/Face Recognition/weights/inception_3b_pool_bn_b.csv
# week4/Face Recognition/weights/inception_4a_1x1_bn_b.csv
# week4/Face Recognition/weights/inception_3c_5x5_conv1_b.csv
# week4/Face Recognition/weights/inception_3b_1x1_bn_b.csv
# week4/Face Recognition/weights/inception_3c_5x5_bn2_w.csv
# week4/Face Recognition/weights/inception_4a_3x3_bn1_m.csv
# week4/Face Recognition/weights/bn1_v.csv
# week4/Face Recognition/weights/inception_4a_3x3_conv1_w.csv
# week4/Face Recognition/weights/inception_4a_pool_bn_b.csv
# week4/Face Recognition/weights/inception_3b_5x5_conv2_b.csv
# week4/Face Recognition/weights/conv2_w.csv
# week4/Face Recognition/weights/inception_5b_1x1_conv_b.csv
# week4/Face Recognition/weights/bn2_m.csv
# week4/Face Recognition/weights/inception_3a_3x3_bn1_v.csv
# week4/Face Recognition/weights/inception_4e_5x5_bn1_m.csv
# week4/Face Recognition/weights/inception_5a_3x3_conv2_m.csv
# week4/Face Recognition/weights/inception_3a_5x5_bn1_b.csv
# week4/Face Recognition/weights/inception_5b_pool_conv_b.csv
# week4/Face Recognition/weights/inception_5b_3x3_bn2_b.csv
# week4/Face Recognition/weights/inception_4e_5x5_conv1_w.csv
# week4/Face Recognition/weights/inception_3a_5x5_bn2_m.csv
# week4/Face Recognition/weights/inception_4e_5x5_conv2_b.csv
# week4/Face Recognition/weights/inception_3b_5x5_bn1_m.csv
# week4/Face Recognition/weights/inception_4a_pool_bn_v.csv
# week4/Face Recognition/weights/inception_3a_5x5_conv2_w.csv
# week4/Face Recognition/weights/inception_3b_5x5_conv1_w.csv
# week4/Face Recognition/weights/inception_3b_1x1_bn_v.csv
# week4/Face Recognition/weights/inception_3a_3x3_bn1_b.csv
# week4/Face Recognition/weights/inception_3a_pool_bn_w.csv
# week4/Face Recognition/weights/conv3_b.csv
# week4/Face Recognition/weights/inception_4a_5x5_bn1_m.csv
# week4/Face Recognition/weights/inception_4e_3x3_bn1_m.csv
# week4/Face Recognition/weights/inception_3a_1x1_bn_w.csv
# week4/Face Recognition/weights/inception_3b_pool_bn_v.csv
# week4/Face Recognition/weights/inception_4e_3x3_conv1_w.csv
# week4/Face Recognition/weights/inception_4a_1x1_bn_v.csv
# week4/Face Recognition/weights/inception_4a_5x5_conv1_w.csv
# week4/Face Recognition/weights/inception_5a_1x1_bn_m.csv
# week4/Face Recognition/weights/inception_3c_3x3_bn2_w.csv
# week4/Face Recognition/weights/inception_5a_pool_conv_w.csv
# week4/Face Recognition/weights/inception_5b_3x3_bn2_v.csv
# week4/Face Recognition/weights/inception_3c_3x3_conv1_b.csv
# week4/Face Recognition/weights/inception_3b_3x3_conv2_b.csv
# week4/Face Recognition/weights/inception_5b_3x3_bn1_w.csv
# week4/Face Recognition/weights/inception_5a_3x3_bn2_w.csv
# week4/Face Recognition/weights/inception_5a_1x1_conv_w.csv
# week4/Face Recognition/weights/inception_5a_3x3_conv1_b.csv
# week4/Face Recognition/weights/inception_3a_5x5_bn1_v.csv
# week4/Face Recognition/weights/inception_5a_pool_bn_m.csv
# week4/Face Recognition/weights/bn1_b.csv
# week4/Face Recognition/weights/inception_4a_3x3_conv2_b.csv
# week4/Face Recognition/weights/inception_3c_3x3_bn2_m.csv
# week4/Face Recognition/weights/inception_5b_pool_bn_b.csv
# week4/Face Recognition/weights/inception_3c_3x3_conv2_w.csv
# week4/Face Recognition/weights/inception_5b_3x3_conv1_w.csv
# week4/Face Recognition/weights/inception_4e_5x5_bn2_v.csv
# week4/Face Recognition/weights/inception_5a_3x3_bn2_m.csv
# week4/Face Recognition/weights/inception_5b_3x3_bn1_m.csv
# week4/Face Recognition/weights/inception_4e_5x5_bn1_w.csv
# week4/Face Recognition/weights/inception_5a_3x3_conv2_w.csv
# week4/Face Recognition/weights/inception_5b_1x1_bn_b.csv
# week4/Face Recognition/weights/conv1_b.csv
# week4/Face Recognition/weights/bn2_w.csv
# week4/Face Recognition/weights/bn3_v.csv
# week4/Face Recognition/weights/inception_3a_pool_bn_m.csv
# week4/Face Recognition/weights/inception_5a_3x3_bn1_v.csv
# week4/Face Recognition/weights/inception_3a_1x1_bn_m.csv
# week4/Face Recognition/weights/inception_3b_3x3_bn1_w.csv
# week4/Face Recognition/weights/inception_3a_3x3_conv1_b.csv
# week4/Face Recognition/weights/inception_3a_3x3_bn2_w.csv
# week4/Face Recognition/weights/inception_4a_5x5_bn2_b.csv
# week4/Face Recognition/weights/dense_b.csv
# week4/Face Recognition/weights/inception_3a_1x1_conv_w.csv
# week4/Face Recognition/weights/inception_3b_3x3_bn2_v.csv
# week4/Face Recognition/weights/inception_3a_pool_conv_w.csv
# week4/Face Recognition/weights/inception_4e_3x3_bn2_b.csv
# week4/Face Recognition/weights/inception_3c_3x3_bn1_v.csv
# week4/Face Recognition/weights/inception_3b_5x5_bn2_b.csv
# week4/Face Recognition/weights/inception_3c_5x5_bn1_b.csv
# week4/Face Recognition/weights/inception_4a_3x3_bn1_w.csv
# week4/Face Recognition/weights/inception_4a_3x3_bn2_v.csv
# week4/Face Recognition/weights/inception_3b_1x1_conv_b.csv
# week4/Face Recognition/weights/inception_3c_5x5_bn2_m.csv
# week4/Face Recognition/weights/inception_3c_5x5_conv2_w.csv
# week4/Face Recognition/weights/inception_5b_1x1_bn_v.csv
# week4/Face Recognition/weights/inception_4a_pool_conv_b.csv
# week4/Face Recognition/weights/inception_4a_3x3_bn2_b.csv
# week4/Face Recognition/weights/inception_5b_pool_bn_v.csv
# week4/Face Recognition/weights/inception_3b_pool_conv_b.csv
# week4/Face Recognition/weights/inception_5a_1x1_bn_w.csv
# week4/Face Recognition/weights/inception_3b_3x3_bn2_b.csv
# week4/Face Recognition/weights/inception_4a_1x1_conv_b.csv
# week4/Face Recognition/weights/inception_3c_3x3_bn1_b.csv
# week4/Face Recognition/weights/inception_5a_pool_bn_w.csv
# week4/Face Recognition/weights/inception_5a_3x3_bn1_b.csv
# week4/Face Recognition/weights/inception_3b_5x5_bn1_w.csv
# week4/Face Recognition/weights/inception_3a_5x5_conv1_b.csv
# week4/Face Recognition/weights/inception_3a_5x5_bn2_w.csv
# week4/Face Recognition/weights/inception_5b_3x3_conv2_b.csv
# week4/Face Recognition/weights/inception_3b_5x5_bn2_v.csv
# week4/Face Recognition/weights/inception_4e_5x5_bn2_b.csv
# week4/Face Recognition/weights/inception_3c_5x5_bn1_v.csv
# week4/Face Recognition/weights/inception_4a_5x5_bn1_w.csv
# week4/Face Recognition/weights/inception_4e_3x3_bn1_w.csv
# week4/Face Recognition/weights/bn3_b.csv
# week4/Face Recognition/weights/inception_4a_5x5_bn2_v.csv
# week4/Face Recognition/weights/inception_4e_3x3_bn2_v.csv
# week4/Face Recognition/weights/inception_3b_3x3_conv2_w.csv
# week4/Face Recognition/weights/inception_5a_3x3_conv1_w.csv
# week4/Face Recognition/weights/inception_5a_1x1_bn_b.csv
# week4/Face Recognition/weights/inception_5a_3x3_bn1_m.csv
# week4/Face Recognition/weights/inception_3b_3x3_bn2_m.csv
# week4/Face Recognition/weights/inception_3c_3x3_conv1_w.csv
# week4/Face Recognition/weights/inception_5a_pool_bn_b.csv
# week4/Face Recognition/weights/inception_3c_3x3_bn1_m.csv
# week4/Face Recognition/weights/inception_4e_5x5_bn1_v.csv
# week4/Face Recognition/weights/inception_5a_3x3_conv2_v.csv
# week4/Face Recognition/weights/inception_4a_3x3_conv2_w.csv
# week4/Face Recognition/weights/bn2_v.csv
# week4/Face Recognition/weights/inception_4a_3x3_bn2_m.csv
# week4/Face Recognition/weights/bn1_w.csv
# week4/Face Recognition/weights/inception_3c_5x5_conv2_b.csv
# week4/Face Recognition/weights/inception_3b_3x3_bn1_v.csv
# week4/Face Recognition/weights/inception_3a_3x3_bn2_v.csv
# week4/Face Recognition/weights/inception_4e_3x3_bn1_b.csv
# week4/Face Recognition/weights/inception_4a_5x5_bn1_b.csv
# week4/Face Recognition/weights/bn3_m.csv
# week4/Face Recognition/weights/inception_3a_3x3_bn1_w.csv
# week4/Face Recognition/weights/conv3_w.csv
# week4/Face Recognition/weights/inception_4a_3x3_bn1_v.csv
# week4/Face Recognition/weights/inception_4e_5x5_conv2_w.csv
# week4/Face Recognition/weights/inception_3a_5x5_bn2_b.csv
# week4/Face Recognition/weights/inception_3b_5x5_bn1_b.csv
# week4/Face Recognition/weights/inception_4e_5x5_bn2_m.csv
# week4/Face Recognition/weights/inception_4a_3x3_bn1_b.csv
# week4/Face Recognition/weights/inception_4a_pool_bn_w.csv
# week4/Face Recognition/weights/inception_3b_5x5_conv2_w.csv
# week4/Face Recognition/weights/inception_3b_1x1_bn_w.csv
# week4/Face Recognition/weights/inception_3c_5x5_bn1_m.csv
# week4/Face Recognition/weights/inception_3c_5x5_conv1_w.csv
# week4/Face Recognition/weights/inception_3b_5x5_bn2_m.csv
# week4/Face Recognition/weights/inception_3a_pool_conv_b.csv
# week4/Face Recognition/weights/inception_4e_3x3_conv2_w.csv
# week4/Face Recognition/weights/inception_5a_1x1_bn_v.csv
# week4/Face Recognition/weights/inception_3a_1x1_conv_b.csv
# week4/Face Recognition/weights/inception_4a_5x5_conv2_w.csv
# week4/Face Recognition/weights/inception_5a_pool_bn_v.csv
# week4/Face Recognition/weights/inception_4a_1x1_bn_w.csv
# week4/Face Recognition/weights/inception_4e_3x3_bn2_m.csv
# week4/Face Recognition/weights/inception_3b_pool_bn_w.csv
# week4/Face Recognition/weights/inception_3a_3x3_bn2_b.csv
# week4/Face Recognition/weights/inception_4a_5x5_bn2_m.csv
# week4/Face Recognition/weights/inception_3b_3x3_bn1_b.csv
# week4/Face Recognition/weights/inception_5b_pool_conv_w.csv
# week4/Face Recognition/weights/inception_5b_3x3_bn2_w.csv
# week4/Face Recognition/weights/inception_4e_5x5_bn1_b.csv
# week4/Face Recognition/weights/inception_5a_3x3_conv2_b.csv
# week4/Face Recognition/weights/inception_3a_5x5_bn2_v.csv
# week4/Face Recognition/weights/inception_3b_5x5_bn1_v.csv
# week4/Face Recognition/weights/inception_5b_pool_bn_m.csv
# week4/Face Recognition/weights/inception_3a_5x5_bn1_w.csv
# week4/Face Recognition/weights/inception_3c_3x3_conv2_b.csv
# week4/Face Recognition/weights/inception_5b_3x3_conv1_b.csv
# week4/Face Recognition/weights/inception_4e_3x3_bn1_v.csv
# week4/Face Recognition/weights/inception_5b_1x1_conv_w.csv
# week4/Face Recognition/weights/inception_5b_1x1_bn_m.csv
# week4/Face Recognition/weights/inception_4a_5x5_bn1_v.csv
# week4/Face Recognition/weights/bn2_b.csv
# week4/Face Recognition/weights/inception_5b_3x3_bn2_m.csv
# week4/Face Recognition/weights/inception_4e_5x5_bn2_w.csv
# week4/Face Recognition/weights/inception_4e_5x5_conv1_b.csv
# week4/Face Recognition/weights/inception_5b_3x3_conv2_w.csv
# week4/Face Recognition/weights/inception_3a_5x5_bn1_m.csv
# week4/Face Recognition/weights/inception_3a_5x5_conv1_w.csv
# week4/Face Recognition/weights/inception_3a_1x1_bn_v.csv
# week4/Face Recognition/weights/inception_3a_pool_bn_v.csv
# week4/Face Recognition/weights/conv2_b.csv
# week4/Face Recognition/weights/bn3_w.csv
# week4/Face Recognition/weights/inception_3c_3x3_bn2_v.csv
# week4/Face Recognition/weights/inception_5a_3x3_bn1_w.csv
# week4/Face Recognition/weights/inception_3b_3x3_conv1_b.csv
# week4/Face Recognition/weights/inception_4a_1x1_bn_m.csv
# week4/Face Recognition/weights/inception_3a_3x3_conv2_b.csv
# week4/Face Recognition/weights/inception_3c_3x3_bn1_w.csv
# week4/Face Recognition/weights/inception_4a_1x1_conv_w.csv
# week4/Face Recognition/weights/inception_3b_3x3_bn2_w.csv
# week4/Face Recognition/weights/inception_5a_3x3_bn2_v.csv
# week4/Face Recognition/weights/inception_3b_pool_conv_w.csv
# week4/Face Recognition/weights/inception_5b_3x3_bn1_v.csv
# week4/Face Recognition/weights/inception_3b_pool_bn_m.csv
# week4/Face Recognition/weights/inception_3b_1x1_bn_m.csv
# week4/Face Recognition/weights/inception_3b_1x1_conv_w.csv
# week4/Face Recognition/weights/inception_4a_3x3_conv1_b.csv
# week4/Face Recognition/weights/inception_4a_3x3_bn2_w.csv
# week4/Face Recognition/weights/inception_4a_pool_conv_w.csv
# week4/Face Recognition/weights/inception_4a_pool_bn_m.csv
# week4/Face Recognition/weights/inception_3c_5x5_bn2_b.csv
# week4/Face Recognition/weights/conv1_w.csv
# week4/Face Recognition/weights/inception_5b_1x1_bn_w.csv
# week4/Face Recognition/weights/bn1_m.csv
# week4/Face Recognition/weights/inception_5a_1x1_conv_b.csv
# week4/Face Recognition/weights/inception_5b_pool_bn_w.csv
# week4/Face Recognition/weights/inception_5a_3x3_bn2_b.csv
# week4/Face Recognition/weights/inception_5b_3x3_bn1_b.csv
# week4/Face Recognition/weights/inception_5a_pool_conv_b.csv
# week4/Face Recognition/weights/inception_3c_3x3_bn2_b.csv
# week4/Face Recognition/weights/inception_3c_5x5_bn2_v.csv
# week4/Face Recognition/weights/inception_3b_5x5_conv1_b.csv
# week4/Face Recognition/weights/inception_3a_5x5_conv2_b.csv
# week4/Face Recognition/weights/inception_3b_5x5_bn2_w.csv
# week4/Face Recognition/weights/inception_3c_5x5_bn1_w.csv
# week4/Face Recognition/weights/inception_3a_3x3_conv1_w.csv
# week4/Face Recognition/weights/inception_4a_5x5_conv1_b.csv
# week4/Face Recognition/weights/inception_3a_3x3_bn1_m.csv
# week4/Face Recognition/weights/inception_4e_3x3_conv1_b.csv
# week4/Face Recognition/weights/inception_4e_3x3_bn2_w.csv
# week4/Face Recognition/weights/inception_3a_pool_bn_b.csv
# week4/Face Recognition/weights/dense_w.csv
# week4/Face Recognition/weights/inception_4a_5x5_bn2_w.csv
# week4/Face Recognition/weights/inception_3a_1x1_bn_b.csv
# week4/Face Recognition/fr_utils.py
# week4/Face Recognition/nn4.small2.v7.h5
# week4/Neural Style Transfer/
# week4/Neural Style Transfer/Art Generation with Neural Style Transfer - v1.ipynb
# week4/Neural Style Transfer/nst_utils.py
# week4/Neural Style Transfer/pretrained-model/
# week4/Neural Style Transfer/pretrained-model/imagenet-vgg-verydeep-19.mat
# week4/Neural Style Transfer/.ipynb_checkpoints/
# week4/Neural Style Transfer/.ipynb_checkpoints/Art Generation with Neural Style Transfer - v2-checkpoint.ipynb
# week4/Neural Style Transfer/images/
# week4/Neural Style Transfer/images/persian_cat.jpg
# week4/Neural Style Transfer/images/NST_LOSS.png
# week4/Neural Style Transfer/images/circle_abstract.png
# week4/Neural Style Transfer/images/stone_style.jpg
# week4/Neural Style Transfer/images/louvre_small.jpg
# week4/Neural Style Transfer/images/louvre.jpg
# week4/Neural Style Transfer/images/persian_cat_content.jpg
# week4/Neural Style Transfer/images/result.png
# week4/Neural Style Transfer/images/monet.jpg
# week4/Neural Style Transfer/images/gram.png
# week4/Neural Style Transfer/images/drop-of-water.jpg
# week4/Neural Style Transfer/images/sandstone.jpg
# week4/Neural Style Transfer/images/hidden_layers.png
# week4/Neural Style Transfer/images/louvre_generated.png
# week4/Neural Style Transfer/images/content_plus_style.png
# week4/Neural Style Transfer/images/pasargad_kashi.png
# week4/Neural Style Transfer/images/perspolis_vangogh.png
# week4/Neural Style Transfer/images/content300.jpg
# week4/Neural Style Transfer/images/claude-monet.jpg
# week4/Neural Style Transfer/images/style300.jpg
# week4/Neural Style Transfer/images/NST_GM.png
# week4/Neural Style Transfer/images/reshape_loss.png
# week4/Neural Style Transfer/images/cat.jpg
# week4/Neural Style Transfer/images/monet_800600.jpg
# week4/Neural Style Transfer/images/camp-nou.jpg
# week4/Neural Style Transfer/images/content.jpeg
# week4/Neural Style Transfer/Pretrained_Model_LICENSE.txt
# week4/Neural Style Transfer/Art Generation with Neural Style Transfer - v2.ipynb
# week4/Neural Style Transfer/output/
# week4/Neural Style Transfer/output/generated_image.jpg
# week4/Neural Style Transfer/output/140.png
# week4/Neural Style Transfer/output/100.png
# week4/Neural Style Transfer/output/180.png
# week4/Neural Style Transfer/output/160.png
# week4/Neural Style Transfer/output/120.png
# week4/Neural Style Transfer/output/60.png
# week4/Neural Style Transfer/output/20.png
# week4/Neural Style Transfer/output/0.png
# week4/Neural Style Transfer/output/80.png
# week4/Neural Style Transfer/output/40.png
# week4/Neural Style Transfer/__pycache__/
# week4/Neural Style Transfer/__pycache__/nst_utils.cpython-36.pyc

# %% [markdown]
# **Note**: As you can see, we've imported a lot of functions from Keras. You can use them easily just by calling them directly in the notebook. Ex: `X = Input(...)` or `X = ZeroPadding2D(...)`.

# %% [markdown]
# ## 1 - The Happy House
#
# For your next vacation, you decided to spend a week with five of your friends from school. It is a very convenient house with many things to do nearby. But the most important benefit is that everybody has commited to be happy when they are in the house. So anyone wanting to enter the house must prove their current state of happiness.
#
# <img src="images/happy-house.jpg" style="width:350px;height:270px;">
# <caption><center> <u> <font color='purple'> **Figure 1** </u><font color='purple'>  : **the Happy House**</center></caption>
#
#
# As a deep learning expert, to make sure the "Happy" rule is strictly applied, you are going to build an algorithm which that uses pictures from the front door camera to check if the person is happy or not. The door should open only if the person is happy.
#
# You have gathered pictures of your friends and yourself, taken by the front-door camera. The dataset is labbeled.
#
# <img src="images/house-members.png" style="width:550px;height:250px;">
#
# Run the following code to normalize the dataset and learn about its shapes.

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %% [markdown]
# **Details of the "Happy" dataset**:
# - Images are of shape (64,64,3)
# - Training: 600 pictures
# - Test: 150 pictures
#
# It is now time to solve the "Happy" Challenge.

# %% [markdown]
# ## 2 - Building a model in Keras
#
# Keras is very good for rapid prototyping. In just a short time you will be able to build a model that achieves outstanding results.
#
# Here is an example of a model in Keras:
#
# ```python
# def model(input_shape):
#     # Define the input placeholder as a tensor with shape input_shape. Think of this as your input image!
#     X_input = Input(input_shape)
#
#     # Zero-Padding: pads the border of X_input with zeroes
#     X = ZeroPadding2D((3, 3))(X_input)
#
#     # CONV -> BN -> RELU Block applied to X
#     X = Conv2D(32, (7, 7), strides = (1, 1), name = 'conv0')(X)
#     X = BatchNormalization(axis = 3, name = 'bn0')(X)
#     X = Activation('relu')(X)
#
#     # MAXPOOL
#     X = MaxPooling2D((2, 2), name='max_pool')(X)
#
#     # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
#     X = Flatten()(X)
#     X = Dense(1, activation='sigmoid', name='fc')(X)
#
#     # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
#     model = Model(inputs = X_input, outputs = X, name='HappyModel')
#
#     return model
# ```
#
# Note that Keras uses a different convention with variable names than we've previously used with numpy and TensorFlow. In particular, rather than creating and assigning a new variable on each step of forward propagation such as `X`, `Z1`, `A1`, `Z2`, `A2`, etc. for the computations for the different layers, in Keras code each line above just reassigns `X` to a new value using `X = ...`. In other words, during each step of forward propagation, we are just writing the latest value in the commputation into the same variable `X`. The only exception was `X_input`, which we kept separate and did not overwrite, since we needed it at the end to create the Keras model instance (`model = Model(inputs = X_input, ...)` above).
#
# **Exercise**: Implement a `HappyModel()`. This assignment is more open-ended than most. We suggest that you start by implementing a model using the architecture we suggest, and run through the rest of this assignment using that as your initial model. But after that, come back and take initiative to try out other model architectures. For example, you might take inspiration from the model above, but then vary the network architecture and hyperparameters however you wish. You can also use other functions such as `AveragePooling2D()`, `GlobalMaxPooling2D()`, `Dropout()`.
#
# **Note**: You have to be careful with your data's shapes. Use what you've learned in the videos to make sure your convolutional, pooling and fully-connected layers are adapted to the volumes you're applying it to.

# %%
# GRADED FUNCTION: HappyModel

def HappyModel(input_shape):
    """
    Implementation of the HappyModel.
    
    Arguments:
    input_shape -- shape of the images of the dataset

    Returns:
    model -- a Model() instance in Keras
    """
    
    ### START CODE HERE ###
    # Feel free to use the suggested outline in the text above to get started, and run through the whole
    # exercise (including the later portions of this notebook) once. The come back also try out other
    # network architectures as well. 
    X_input = Input(input_shape)

    # Zero-Padding: pads the border of X_input with zeroes
    X = ZeroPadding2D((3, 3))(X_input)

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(32, (7, 7), strides = (1, 1), name = 'conv0')(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X)

    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool')(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED
    X = Flatten()(X)
    X = Dense(1, activation='sigmoid', name='fc')(X)

    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs = X_input, outputs = X, name='HappyModel')

    
    ### END CODE HERE ###
    
    return model

# %% [markdown]
# You have now built a function to describe your model. To train and test this model, there are four steps in Keras:
# 1. Create the model by calling the function above
# 2. Compile the model by calling `model.compile(optimizer = "...", loss = "...", metrics = ["accuracy"])`
# 3. Train the model on train data by calling `model.fit(x = ..., y = ..., epochs = ..., batch_size = ...)`
# 4. Test the model on test data by calling `model.evaluate(x = ..., y = ...)`
#
# If you want to know more about `model.compile()`, `model.fit()`, `model.evaluate()` and their arguments, refer to the official [Keras documentation](https://keras.io/models/model/).
#
# **Exercise**: Implement step 1, i.e. create the model.

# %%
### START CODE HERE ### (1 line)
happyModel = None
### END CODE HERE ###

# %% [markdown]
# **Exercise**: Implement step 2, i.e. compile the model to configure the learning process. Choose the 3 arguments of `compile()` wisely. Hint: the Happy Challenge is a binary classification problem.

# %%
### START CODE HERE ### (1 line)
None
### END CODE HERE ###

# %% [markdown]
# **Exercise**: Implement step 3, i.e. train the model. Choose the number of epochs and the batch size.

# %%
### START CODE HERE ### (1 line)
None
### END CODE HERE ###

# %% [markdown]
# Note that if you run `fit()` again, the `model` will continue to train with the parameters it has already learnt instead of reinitializing them.
#
# **Exercise**: Implement step 4, i.e. test/evaluate the model.

# %%
### START CODE HERE ### (1 line)
preds = None
### END CODE HERE ###
print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))

# %% [markdown]
# If your `happyModel()` function worked, you should have observed much better than random-guessing (50%) accuracy on the train and test sets.
#
# To give you a point of comparison, our model gets around **95% test accuracy in 40 epochs** (and 99% train accuracy) with a mini batch size of 16 and "adam" optimizer. But our model gets decent accuracy after just 2-5 epochs, so if you're comparing different models you can also train a variety of models on just a few epochs and see how they compare.
#
# If you have not yet achieved a very good accuracy (let's say more than 80%), here're some things you can play around with to try to achieve it:
#
# - Try using blocks of CONV->BATCHNORM->RELU such as:
# ```python
# X = Conv2D(32, (3, 3), strides = (1, 1), name = 'conv0')(X)
# X = BatchNormalization(axis = 3, name = 'bn0')(X)
# X = Activation('relu')(X)
# ```
# until your height and width dimensions are quite low and your number of channels quite large (≈32 for example). You are encoding useful information in a volume with a lot of channels. You can then flatten the volume and use a fully-connected layer.
# - You can use MAXPOOL after such blocks. It will help you lower the dimension in height and width.
# - Change your optimizer. We find Adam works well.
# - If the model is struggling to run and you get memory issues, lower your batch_size (12 is usually a good compromise)
# - Run on more epochs, until you see the train accuracy plateauing.
#
# Even if you have achieved a good accuracy, please feel free to keep playing with your model to try to get even better results.
#
# **Note**: If you perform hyperparameter tuning on your model, the test set actually becomes a dev set, and your model might end up overfitting to the test (dev) set. But just for the purpose of this assignment, we won't worry about that here.

# %% [markdown]
# ## 3 - Conclusion
#
# Congratulations, you have solved the Happy House challenge!
#
# Now, you just need to link this model to the front-door camera of your house. We unfortunately won't go into the details of how to do that here.

# %% [markdown]
# <font color='blue'>
# **What we would like you to remember from this assignment:**
# - Keras is a tool we recommend for rapid prototyping. It allows you to quickly try out different model architectures. Are there any applications of deep learning to your daily life that you'd like to implement using Keras?
# - Remember how to code a model in Keras and the four steps leading to the evaluation of your model on the test set. Create->Compile->Fit/Train->Evaluate/Test.

# %% [markdown]
# ## 4 - Test with your own image (Optional)
#
# Congratulations on finishing this assignment. You can now take a picture of your face and see if you could enter the Happy House. To do that:
#     1. Click on "File" in the upper bar of this notebook, then click "Open" to go on your Coursera Hub.
#     2. Add your image to this Jupyter Notebook's directory, in the "images" folder
#     3. Write your image's name in the following code
#     4. Run the code and check if the algorithm is right (0 is unhappy, 1 is happy)!
#
# The training/test sets were quite similar; for example, all the pictures were taken against the same background (since a front door camera is always mounted in the same position). This makes the problem easier, but a model trained on this data may or may not work on your own data. But feel free to give it a try!

# %%
### START CODE HERE ###
img_path = 'images/my_image.jpg'
### END CODE HERE ###
img = image.load_img(img_path, target_size=(64, 64))
imshow(img)

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

print(happyModel.predict(x))

# %% [markdown]
# ## 5 - Other useful functions in Keras (Optional)
#
# Two other basic features of Keras that you'll find useful are:
# - `model.summary()`: prints the details of your layers in a table with the sizes of its inputs/outputs
# - `plot_model()`: plots your graph in a nice layout. You can even save it as ".png" using SVG() if you'd like to share it on social media ;). It is saved in "File" then "Open..." in the upper bar of the notebook.
#
# Run the following code.

# %%
happyModel.summary()

# %%
plot_model(happyModel, to_file='HappyModel.png')
SVG(model_to_dot(happyModel).create(prog='dot', format='svg'))
